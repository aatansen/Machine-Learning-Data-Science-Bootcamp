# %% [markdown]
# # Heart Disease Project
# This project is about claissifying whether a patient has heart
# disease or not.

# %%
import pandas as pd

# %%
df = pd.read_csv("heart-disease.csv")

# %% [markdown]
# <strong>The following table shows heart disease information for patients.</strong>

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.target.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B6BF-70FA
#
#  Directory of C:\Users\Tansen\Ai Lab\Heart Disease Project
#
# 24-Mar-22  10:31 PM    <DIR>          .
# 24-Mar-22  10:31 PM    <DIR>          ..
# 24-Mar-22  10:06 PM    <DIR>          .ipynb_checkpoints
# 24-Mar-22  10:26 PM           332,025 6-step-ml-framework.png
# 24-Mar-22  10:31 PM            16,100 Heart_Disease_Project.ipynb
# 24-Mar-22  10:07 PM            11,328 heart-disease.csv
#                3 File(s)        359,453 bytes
#                3 Dir(s)  52,098,379,776 bytes free

# %% [markdown]
# <strong>showing the image using markdown:</strong>

# %% [markdown]
# ![](6-step-ml-framework.png)
