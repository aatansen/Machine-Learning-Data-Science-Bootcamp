# %% [markdown]
# # Introduction to Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot()
# Out:
# []

# %% [markdown]
# ### remove that `[]` from plot in 2 ways

# %%
# by adding ; at the end
plt.plot()
# Out:
# []

# %%
# 2nd way:
plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4])
plt.show()

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y)
plt.show()

# %%
# 1st method
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
# 2nd method
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
# 3rd method (use this)
fig, ax = plt.subplots()
ax.plot(x, y)

# %% [markdown]
# ### Anatomy of Matplotlib
# ![](matplotlib-anatomy.png)

# %%
# 3rd method (use this)
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250])  # add some data

# %%
# This is where the object orientated name comes from
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ### Matplotlib example workflow

# %%
# 0. Import and get matplotlib ready
import matplotlib.pyplot as plt
# %matplotlib inline

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10, 10))  # (width,height)

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Sample Simple Plot", xlabel="x-axis", ylabel="y-axis")

# 5. Save & show
fig.savefig("images/simple-plot.png")

# %% [markdown]
# ### Making figures with Numpy arrays
#
# We want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %% [markdown]
# ### Line plot

# %%
# Create an array
x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
# Plot the data
fig, ax = plt.subplots()
ax.plot(x, x**2)

# %% [markdown]
# ### Scatter plot

# %%
# use the same data to make scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %% [markdown]
# ### Bar plot

# %%
# Make a plot from a dictionary
nut_butter_prices = {'Almond butter': 10,
                     'Peanut butter': 8,
                     'Cashew butter': 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Dan's Nut Butter store", ylabel="Price ($)")
plt.show()

# %% [markdown]
# ### Horizontal bar

# %%
# Horizontal bar
fig, ax = plt.subplots()
# error unhashable type: 'dict_keys' , need to convert dict to list
# ax.barh(nut_butter_prices.keys(), nut_butter_prices.values())
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### Histogram

# %%
# generating normal distribution 'randn()'
# things to remember: normal distribution is just a curve in x axis
x = np.random.randn(1000)
x
# Out:
# array([-6.01630894e-01,  7.06097437e-01, -9.50112006e-01, -2.54506201e+00,
#        -3.88307990e-01, -1.81112015e+00,  1.38743099e-01,  3.39479560e-01,
#        -2.85397045e-01, -1.07929819e+00,  1.73077085e+00,  2.12269909e-01,
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10, 5))
# Plot to each different axis
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
# Out:
# (array([  2.,  21.,  72., 166., 269., 252., 142.,  52.,  21.,   3.]),
#  array([-3.29996149, -2.62996303, -1.95996457, -1.28996611, -0.61996765,
#          0.05003081,  0.72002927,  1.39002773,  2.06002619,  2.73002465,
#          3.40002311]),
#  <BarContainer object of 10 artists>)

# %%
# Subplot option 2
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10, 5))
ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000))
# Out:
# (array([  1.,  11.,  33., 137., 269., 282., 176.,  75.,  13.,   3.]),
#  array([-3.94545246, -3.18410651, -2.42276056, -1.66141462, -0.90006867,
#         -0.13872272,  0.62262322,  1.38396917,  2.14531512,  2.90666107,
#          3.66800701]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Plotting from pandas Dataframes

# %%
# Make a datafram
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2022', periods=1000))
ts
# Out:
# 2022-01-01    1.432674
# 2022-01-02   -0.686028
# 2022-01-03   -1.824475
# 2022-01-04    0.437656
# 2022-01-05    0.229226
#                 ...
# 2024-09-22    0.182936
# 2024-09-23   -0.756542
# 2024-09-24   -0.327179
# 2024-09-25   -0.708484
# 2024-09-26    1.132243
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Now let's do this with car-sales file

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# fixing price
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]', '', regex=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# remove last two '0' digit
type(car_sales['Price'][0])
# Out:
# str

# %%
car_sales['Price'] = car_sales['Price'].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Sale Date'] = pd.date_range('1/1/2022', periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2022-01-01
# 1   Honda    Red          87899      4   5000 2022-01-02
# 2  Toyota   Blue          32549      3   7000 2022-01-03
# 3     BMW  Black          11179      5  22000 2022-01-04
# 4  Nissan  White         213095      4   3500 2022-01-05
# 5  Toyota  Green          99213      4   4500 2022-01-06
# 6   Honda   Blue          45698      4   7500 2022-01-07
# 7   Honda   Blue          54738      4   7000 2022-01-08
# 8  Toyota  White          60000      4   6250 2022-01-09
# 9  Nissan  White          31600      4   9700 2022-01-10

# %%
car_sales['Price'] = car_sales['Price'].astype(int)
car_sales['Total Sales'] = car_sales['Price'].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2022-01-01         4000
# 1   Honda    Red          87899      4   5000 2022-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03        16000
# 3     BMW  Black          11179      5  22000 2022-01-04        38000
# 4  Nissan  White         213095      4   3500 2022-01-05        41500
# 5  Toyota  Green          99213      4   4500 2022-01-06        46000
# 6   Honda   Blue          45698      4   7500 2022-01-07        53500
# 7   Honda   Blue          54738      4   7000 2022-01-08        60500
# 8  Toyota  White          60000      4   6250 2022-01-09        66750
# 9  Nissan  White          31600      4   9700 2022-01-10        76450

# %%
# lets plot the ttotal sales
car_sales.plot(x='Sale Date', y='Total Sales')
# Out:
# <AxesSubplot:xlabel='Sale Date'>

# %%
car_sales.plot(x='Odometer (KM)', y='Price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
car_sales.plot(x='Odometer (KM)', y='Price', kind='bar')
# Out:
# <AxesSubplot:xlabel='Odometer (KM)'>

# %%
car_sales.plot(x='Odometer (KM)', y='Price', kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Bar Graph

# %%
x = np.random.rand(10, 4)

# turn x into dataframe
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.858935  0.929280  0.422660  0.828815
# 1  0.331811  0.339982  0.377094  0.338235
# 2  0.468655  0.387084  0.576797  0.665380
# 3  0.260585  0.755045  0.214490  0.658288
# 4  0.369898  0.294235  0.718629  0.951716
# 5  0.055746  0.868288  0.317278  0.372637
# 6  0.367037  0.787247  0.927663  0.069548
# 7  0.269794  0.135138  0.390075  0.081787
# 8  0.642124  0.841878  0.933542  0.278439
# 9  0.289174  0.509507  0.083953  0.401819

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
# fixing legend location:
df.plot.bar().legend(loc='upper right')

# %%
df.plot(kind='bar').legend(loc='upper right')

# %%
car_sales.plot(x='Make', y='Odometer (KM)', kind='bar')
# Out:
# <AxesSubplot:xlabel='Make'>

# %% [markdown]
# ### dot and kind method

# %%
# using dot
car_sales['Odometer (KM)'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# using kind
car_sales['Odometer (KM)'].plot(kind='hist', bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### bins (default is 10)

# %%
car_sales['Odometer (KM)'].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Another dataset

# %%
heart_disease = pd.read_csv('heart-disease.csv')
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease['age'].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>],
#       dtype=object)

# %%
# fixing the hist more viewable by adding figure size
heart_disease.plot.hist(figsize=(10, 30), subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# ### Which one is better? (pyplot vs matplotlib OO method)
# * for quick visualization pyplot
# * for more advanced visualization matplotlib OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ### Filtering data

# %%
# let's get the data of patiet that age over 50
over_50 = heart_disease[heart_disease['age'] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot method
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target')
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
# Now doing it using OO method which will give more better view
# OO method
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax=ax)
# ax.set_xlim([45,100]);
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %% [markdown]
# ### OO method from scratch

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(over_50["age"],
                     over_50["chol"],
                     c=over_50["target"])
# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")
# add legend
ax.legend(*scatter.legend_elements(), title="Target")
# add a horizontal line
ax.axhline(over_50["chol"].mean(),
           linestyle="--")

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplot of chol,age,thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10, 10),
                               sharex=True)
# Add data for ax0
scatter = ax0.scatter(over_50["age"],
                      over_50["chol"],
                      c=over_50["target"])
# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(),
            color='b',
            linestyle='--',
            label="Average")

# Add data for ax1
scatter = ax1.scatter(over_50["age"],
                      over_50["thalach"],
                      c=over_50["target"])

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(),
            color='b',
            linestyle='--')
# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ### Customizing Matplotlib plots and getting stylish

# %%
# see the available style
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2022-01-01         4000
# 1   Honda    Red          87899      4   5000 2022-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03        16000
# 3     BMW  Black          11179      5  22000 2022-01-04        38000
# 4  Nissan  White         213095      4   3500 2022-01-05        41500

# %%
car_sales['Price'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales['Price'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('seaborn')
car_sales['Price'].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
plt.style.use('ggplot')
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Changing the title, legend, axes

# %%
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.04072852, -0.86865505, -0.13590052, -2.0799983 ],
#        [-0.95863131, -0.98659611, -1.04055327,  0.28847778],
#        [ 1.09326811,  1.07129051,  0.02045883,  0.41877007],
#        [ 0.50859606, -0.81986981,  1.21465824,  0.81881377],
#        [ 0.43154243, -0.68761955,  0.4534205 ,  0.32872221],
#        [ 0.29481006, -1.2835592 ,  1.17462573, -0.42302799],
#        [ 1.48086684,  0.86991858,  1.20433075, -0.64518955],
#        [ 0.88708795, -0.51785918, -0.08512679, -1.04227905],
#        [-0.78769887, -1.64295294, -2.1825476 ,  2.73060296],
#        [-0.93997173,  0.84772875, -1.32431584,  1.33226456]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.040729 -0.868655 -0.135901 -2.079998
# 1 -0.958631 -0.986596 -1.040553  0.288478
# 2  1.093268  1.071291  0.020459  0.418770
# 3  0.508596 -0.819870  1.214658  0.818814
# 4  0.431542 -0.687620  0.453421  0.328722
# 5  0.294810 -1.283559  1.174626 -0.423028
# 6  1.480867  0.869919  1.204331 -0.645190
# 7  0.887088 -0.517859 -0.085127 -1.042279
# 8 -0.787699 -1.642953 -2.182548  2.730603
# 9 -0.939972  0.847729 -1.324316  1.332265

# %%
ax = df.plot(kind='bar')
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# ### Customize our plot with the set() method

# %%
ax = df.plot(kind='bar')
# Add come labels and a title
ax.set(title="Random Number Bar Graph from DataFrame",
       xlabel="Row number",
       ylabel="Random number")
ax.legend().set_visible(True)

# %% [markdown]
# ### Changing the cmap

# %%
plt.style.use('seaborn-whitegrid')
# No cmap change
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(over_50["age"],
                     over_50["chol"],
                     c=over_50["target"])
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")
ax.axhline(y=over_50["chol"].mean(),
           c='b',
           linestyle='--',
           label="Average")
ax.legend(*scatter.legend_elements(), title="Target")

# %% [markdown]
# ### Customizing the x and y axis limitations

# %%
# Before the change (we've had color updates)

fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))
scatter = ax0.scatter(over_50["age"],
                      over_50["chol"],
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(),
            color='r',
            linestyle='--',
            label="Average")
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"],
                      over_50["thalach"],
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(),
            color='r',
            linestyle='--',
            label="Average")
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %%
# After adding in different x & y limitations

fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))
scatter = ax0.scatter(over_50["age"],
                      over_50["chol"],
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Set the x axis
ax0.set_xlim([50, 80])

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(),
            color='r',
            linestyle='--',
            label="Average")
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"],
                      over_50["thalach"],
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Set the y axis
ax1.set_ylim([60, 200])

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(),
            color='r',
            linestyle='--',
            label="Average")
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ### Saving plots
# * Saving plots to images using figsave()
# If you're doing something like this often, to save writing excess code, you might put it into a function.
#
# A function which follows the Matplotlib workflow.

# %%
# The figure is in fig
fig

# %%
# Check the supported filetypes
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
# Save the file
fig.savefig("./images/heart-disease-analysis.png")

# %%
# Resets figure
fig, ax = plt.subplots()
